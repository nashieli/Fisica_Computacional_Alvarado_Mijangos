# %% [markdown]
# ### Ejercicio 1: Resolver oscilador amortiguado

# %%
f(x,t) = [x[2],-x[1]-x[2]] #Se define la función asociada al sistema de ecuaciones del oscilador 
#armónico amortiguado.
# Out:
# f (generic function with 1 method)

# %% [markdown]
# A continuación se presenta el método de Euler vectorial.

# %%
function metodo_euler(f,list,x0) #Se crea una función que implementa el método de Euler vectorial. 
    #Dicha función toma como entradas la función, una lista y el valor inicial x0.
     x = x0 #Se asigna a x el valor inicial x0.
     h = list[2]-list[1] #Se escribe el paso de h.
     listx = [] #Se crea un vector vacío.
     for i in 2:length(list)
        t = i*h #Se calculan los valores de t.
        x = x + f(x,t)*h #Se realiza la operación del método de Euler.
        push!(listx,x) #Se guarda en listx los valores de x que se obtienen del método de Euler.
     end
     return listx #Se regresa la lista de x.
end
# Out:
# metodo_euler (generic function with 1 method)

# %%
list = 0:0.01:500 #Se crea una lista particular para realizar el método de Euler.
vec = metodo_euler(f,list,[1,0]) #Se crea un vector particular para realizar el método de 
#Euler,con condiciones iniciales x(0)=1, x'(0)=1.
# Out:
# 50000-element Array{Any,1}:
#  [1.0,-0.01]
#  [0.9999,-0.0199]
#  [0.9997010000000001,-0.0297]
#  [0.9994040000000001,-0.03940001]
#  [0.9990099999000001,-0.0490000499]
#  [0.998519999401,-0.05850014940000001]
#  [0.997934997907,-0.06790034790001001]
#  [0.997255994428,-0.07720069440007991]
#  [0.9964839874839991,-0.08640124740035912]
#  [0.9956199750099956,-0.09550207480119552]
#  [0.9946649542619836,-0.10450325380328351]
#  [0.9936199217239509,-0.11340487080787051]
#  [0.9924858730158722,-0.12220702131703132]
#  ⋮
#  [6.061623120076256e-109,-1.154965127522583e-108]
#  [5.946126607323998e-109,-1.1494770993674333e-108]
#  [5.831178897387254e-109,-1.143928454981083e-108]
#  [5.716786051889146e-109,-1.1383203493286595e-108]
#  [5.60295401695628e-109,-1.132653931887262e-108]
#  [5.489688623767554e-109,-1.1269303465853458e-108]
#  [5.376995589109019e-109,-1.1211507317432598e-108]
#  [5.264880515934693e-109,-1.1153162200149363e-108]
#  [5.1533488939332e-109,-1.1094279383307216e-108]
# ...

# %%
listx1 = map(x->x[1],vec) #Guarda  los elementos x[1] de cada elemeno de vec en listx1.
listx2 = map(x->x[2],vec) #Guarda  los elementos x[2] de cada elemeno de vec en listx2.
# Out:
# 50000-element Array{Any,1}:
#  -0.01
#  -0.0199
#  -0.0297
#  -0.0394
#  -0.049
#  -0.0585001
#  -0.0679003
#  -0.0772007
#  -0.0864012
#  -0.0955021
#  -0.104503
#  -0.113405
#  -0.122207
#   ⋮
#  -1.15497e-108
#  -1.14948e-108
#  -1.14393e-108
#  -1.13832e-108
#  -1.13265e-108
#  -1.12693e-108
#  -1.12115e-108
#  -1.11532e-108
#  -1.10943e-108
#  -1.10349e-108
#  -1.09749e-108
#  -1.09145e-108

# %%
using PyPlot

# %%
xlabel("x");ylabel("u")
plot(listx1,listx2) #Se grafica la posición contra la velocidad.
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64d38153d0>)
# /home/danielsandy/.julia/v0.4/Conda/deps/usr/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# A continuación se presenta el método de Runge-Kutta vectorial.

# %%
function Runge_Kutta_orden_4_vec(f,list,x0) #Se crea una función que permite, mediante el método de Runge-Kutta de
    #orden 4 vectorial, obtener la solución aproximada de una ecuación diferencial. Las entradas de esta 
    #función son la función, el valor inicial x0 y una lista.
    
    x = x0
    h = list[2]-list[1]#calculamos el tamaño del paso
    listx = [] #Se crea un vector en donde se guardan los valores xk del método de Runge-Kutta de 
    #orden 4.
    push!(listx,x)#se  gurada la los valores de x en listx
    
        for i in 2:length(list) #Se realiza un for donde se da un intervalo a i cuyo tamaño es el
        #de la lista t.
            t = i*h
            #Se definen funciones necesarias para implementar el método de Runge-Kutta de orden 4.
            k1 = f(x,t)
            k2 = f(x + ((h/2) * k1),t + h/2)
            k3 = f(x + ((h/2) * k2),t + h/2)
            k4 = f(x + h * k3,t + h)
            x = x + (h/6) * (k1 + 2 * k2 + 2 * k3 + k4)#Se realiza la operación que determina los 
            #valores xk.
            push!(listx,x) #Se guarda el valor de xk en la lista x.
        end
     return listx #Se regresa la lista listx.
end
# Out:
# Runge_Kutta_orden_4_vec (generic function with 1 method)

# %%
list1 = 0:0.1:200 #Se crea una lista particular para realizar el método de Euler.
vec1 = Runge_Kutta_orden_4_vec(f,list1,[1,0]) #definimos un vector donde usando método de Runge Kutta con 
#condiciones iniciales x(0)=1, x'(0)=1
# Out:
# 2001-element Array{Any,1}:
#  [1,0]
#  [0.9951666666666666,-0.09500416666666665]
#  [0.9813309027604167,-0.18006416803819442]
#  [0.9594809571660794,-0.2553175363026823]
#  [0.9305872361012872,-0.3209819605401623]
#  [0.8955947741173134,-0.37734558893117326]
#  [0.8554166628206643,-0.4247575838822942]
#  [0.8109284086582803,-0.4636189958055038]
#  [0.7629631850024265,-0.49437401200267783]
#  [0.712307938576277,-0.5175016281678618]
#  [0.6597003059404275,-0.5335077814801433]
#  [0.6058262922720123,-0.5429179761622349]
#  [0.551318661965718,-0.5462704247591967]
#  ⋮
#  [-3.6492576204057083e-44,-3.796296602846927e-44]
#  [-3.9922835370800507e-44,-3.0705891615815695e-44]
#  [-4.2647062644559193e-44,-2.384745645624827e-44]
#  [-4.4706542902855976e-44,-1.7414937374970106e-44]
#  [-4.614495289168673e-44,-1.1428965711763116e-44]
#  [-4.70077183160182e-44,-5.903963552167677e-45]
#  [-4.734141548146151e-44,-8.485974855134244e-46]
#  [-4.719321893691442e-44,3.733756092583205e-45]
# ...

# %%
listx3 = map(x->x[1],vec1) #Guarda  los elementos x[1] de cada elemeno de vec1 en listx3.
listx4 = map(x->x[2],vec1) #Guarda  los elementos x[2] de cada elemeno de vec1 en listx4.
# Out:
# 2001-element Array{Any,1}:
#   0
#  -0.0950042
#  -0.180064
#  -0.255318
#  -0.320982
#  -0.377346
#  -0.424758
#  -0.463619
#  -0.494374
#  -0.517502
#  -0.533508
#  -0.542918
#  -0.54627
#   ⋮
#  -3.7963e-44
#  -3.07059e-44
#  -2.38475e-44
#  -1.74149e-44
#  -1.1429e-44
#  -5.90396e-45
#  -8.48597e-46
#   3.73376e-45
#   7.84454e-45
#   1.14895e-44
#   1.46784e-44
#   1.74243e-44

# %%
xlabel("x");ylabel("u")
plot(listx3,listx4) #Se grafica posición contra velocidad usando Runge-Kutta.
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64d10a3b10>)

# %% [markdown]
# ### Ejercicio 2. Resolver el péndulo simple

# %%
F(x,t) = [x[2],-sin(x[1])] #Se define la función para el péndulo simple.
# Out:
# F (generic function with 1 method)

# %%
lista = 0:0.01:200 #Se define una lista de t. 
    for i in 1:10 #Se realiza un for donde se grafican x y u para 10 condiciones iniciales aleatorias.
        x = rand()-1 #Se asigna una condición inicial x0 aleatoriamente.
        u = rand()-1 #Se asigna una condición inicial u0 aleatoriamente.
        ax = axes()
        vec1 = Runge_Kutta_orden_4_vec(F,lista,[x,u]) 
        listx3 = map(x->x[1],vec1)
        listx4 = map(x->x[2],vec1)

        xlabel("θ")
        ylabel("θ'")
        plot(listx3,listx4,label="θ(0)=$x,θ'(0)=$u")
        legend(bbox_to_anchor=[1.05,1],loc = 2,borderaxespad = 0)
        ax[:set_position]([0.04,0.06,0.7,0.8])
    end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64d0b18c10>)

# %% [markdown]
# ### Ejercicio 3. Comprobación numérica con Runge-Kutta (primer sistema)

# %%
G(x,t) = (x[1]^2) - 1 #Se define la función del sistema.
# Out:
# G (generic function with 1 method)

# %%
lista = 0:0.01:5 #Se define una lista de t.
    for i in 1:10 #Se realiza un for donde se grafica x para 10 condiciones iniciales aleatorias.
        x = rand() #Se asigna una condición inicial x0 aleatoriamente.
        ax = axes()
        vec1 = Runge_Kutta_orden_4_vec(G,lista,x)
        listx3 = map(x->x[1],vec1)

        xlabel("t")
        ylabel("x")
        plot(lista,listx3,label="x(0)=$x")
        legend(bbox_to_anchor=[1.05,1],loc = 2,borderaxespad = 0)
        ax[:set_position]([0.06,0.06,0.8,0.8])
    end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64d0d73050>)

# %% [markdown]
# ### Ejercicio 4. Comprobación numérica con Runge-Kutta (segundo sistema)

# %%
H(x,t) = x[1]^2 #Se define la función del sistema.
# Out:
# H (generic function with 1 method)

# %%
lista = 0:0.01:40 #Se define una lista de t.
    for i in 1:20 #Se realiza un for donde se grafica x para 20 condiciones iniciales aleatorias.
        x = rand() - 1 #Se asigna una condición inicial x0 aleatoriamente.
        ax = axes()
        vec1 = Runge_Kutta_orden_4_vec(H,lista,x)
        listx4 = map(x->x[1],vec1)

        xlabel("t")
        ylabel("x")
        plot(lista,listx4,label="x(0)=$x")
        legend(bbox_to_anchor=[1.05,1],loc = 2,borderaxespad = 0)
        ax[:set_position]([0.06,0.06,0.8,0.8])
    end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64d04c7c90>)

# %% [markdown]
# ### Ejercicio 5. Resolver con Runge-Kutta orden $4$ un sistema de ecuaciones

# %%
#Se definen las funciones del sistema.
f1(x,t) = [x[1],x[2]]
f2(x,t) = [-x[1],-x[2]]
f3(x,t) = [x[1],-2x[2]]
f4(x,t) = [x[1]-0.5x[2],0]
f5(x,t) = [x[2],-x[1]]
f6(x,t) = [x[1]+x[2],-x[1]+x[2]]
f7(x,t) = [-x[1]+x[2],-x[1]-x[2]]
f8(x,t) = [-x[1]-x[2],x[1]-x[2]]
f9(x,t) = [x[1]+4x[2],-2x[1]+x[2]]
f10(x,t) = [-x[1]-x[2],-x[2]]
# Out:
# f10 (generic function with 1 method)

# %%
lista = 0:0.01:10 #Se define una lista de t.
    for i in 1:30 #Se realiza un for donde se grafica x para 30 condiciones iniciales aleatorias.
        x = rand() - 1 #Se asigna una condición inicial x0 aleatoriamente.
        u = rand() - 1 #Se asigna una condición inicial u0 aleatoriamente.
        ax = axes()
        vec1 = Runge_Kutta_orden_4_vec(f1,lista,[x,u])   
        listx3 = map(x->x[1],vec1)
        listx4 = map(x->x[2],vec1)

        xlabel("x1")
        ylabel("x2")
        plot(listx3,listx4,label="x1(0)=$x,x2(0)=$u")
        legend(bbox_to_anchor = [1.05,1],loc = 2,borderaxespad = 0)
        ax[:set_position]([0.06,0.06,0.8,0.8])
    end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64d08d3750>)

# %%
lista = 0:0.01:10 #Se define una lista de t.
    for i in 1:20 #Se realiza un for donde se grafica x para 20 condiciones iniciales aleatorias.
        x = rand() - 1 #Se asigna una condición inicial x0 aleatoriamente.
        u = rand() - 1 #Se asigna una condición inicial u0 aleatoriamente.
        ax = axes()
        vec1 = Runge_Kutta_orden_4_vec(f2,lista,[x,u])   
        listx3 = map(x->x[1],vec1)
        listx4 = map(x->x[2],vec1)
    
        xlabel("x1")
        ylabel("x2"),
        plot(listx3,listx4,label="x1(0)=$x,x2(0)=$u");
        legend(bbox_to_anchor = [1.05,1],loc = 2,borderaxespad = 0)
        ax[:set_position]([0.06,0.06,0.8,0.8])
    end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64d0e4a490>)

# %%
lista = 0:0.01:2 #Se define una lista de t.
    for i in 1:20 #Se realiza un for donde se grafica x para 20 condiciones iniciales aleatorias.
        x = rand() - 1 #Se asigna una condición inicial x0 aleatoriamente.
        u = rand() - 1 #Se asigna una condición inicial u0 aleatoriamente.
        ax = axes()
        vec1 = Runge_Kutta_orden_4_vec(f3,lista,[x,u])   
        listx3 = map(x->x[1],vec1)
        listx4 = map(x->x[2],vec1)
    
        xlabel("x1")
        ylabel("x2"),
        plot(listx3,listx4,label="x1(0)=$x,x2(0)=$u");
        legend(bbox_to_anchor = [1.05,1],loc = 2,borderaxespad = 0)
        ax[:set_position]([0.06,0.06,0.8,0.8])
    end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64d04ccd50>)

# %%
lista = 0:0.01:10 #Se define una lista de t.
    for i in 1:20 #Se realiza un for donde se grafica x para 20 condiciones iniciales aleatorias.
        x = rand() - 1 #Se asigna una condición inicial x0 aleatoriamente.
        u = rand() - 1 #Se asigna una condición inicial u0 aleatoriamente.
        ax = axes()
        vec1 = Runge_Kutta_orden_4_vec(f4,lista,[x,u])   
        listx3 = map(x->x[1],vec1)
        listx4 = map(x->x[2],vec1)
    
        xlabel("x1")
        ylabel("x2"),
        plot(listx3,listx4,label="x1(0)=$x,x2(0)=$u");
        legend(bbox_to_anchor = [1.05,1],loc = 2,borderaxespad = 0)
        ax[:set_position]([0.06,0.06,0.8,0.8])
    end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64cff7d3d0>)

# %%
lista = 0:0.01:10 #Se define una lista de t.
    for i in 1:20 #Se realiza un for donde se grafica x para 20 condiciones iniciales aleatorias.
        x = rand() - 1 #Se asigna una condición inicial x0 aleatoriamente.
        u = rand() - 1 #Se asigna una condición inicial u0 aleatoriamente.
        ax = axes()
        vec1 = Runge_Kutta_orden_4_vec(f5,lista,[x,u])   
        listx3 = map(x->x[1],vec1)
        listx4 = map(x->x[2],vec1)
    
        xlabel("x1")
        ylabel("x2"),
        plot(listx3,listx4,label="x1(0)=$x,x2(0)=$u");
        legend(bbox_to_anchor = [1.05,1],loc = 2,borderaxespad = 0)
        ax[:set_position]([0.06,0.06,0.8,0.8])
    end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64d0fa1290>)

# %%
lista = 0:0.01:10 #Se define una lista de t.
    for i in 1:20 #Se realiza un for donde se grafica x para 20 condiciones iniciales aleatorias.
        x = rand() - 1 #Se asigna una condición inicial x0 aleatoriamente.
        u = rand() - 1 #Se asigna una condición inicial u0 aleatoriamente.
        ax = axes()
        vec1 = Runge_Kutta_orden_4_vec(f6,lista,[x,u])   
        listx3 = map(x->x[1],vec1)
        listx4 = map(x->x[2],vec1)
    
        xlabel("x1")
        ylabel("x2"),
        plot(listx3,listx4,label="x1(0)=$x,x2(0)=$u");
        legend(bbox_to_anchor = [1.05,1],loc = 2,borderaxespad = 0)
        ax[:set_position]([0.06,0.06,0.8,0.8])
    end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64d00a76d0>)

# %%
lista = 0:0.01:10 #Se define una lista de t.
    for i in 1:20 #Se realiza un for donde se grafica x para 20 condiciones iniciales aleatorias.
        x = rand() - 1 #Se asigna una condición inicial x0 aleatoriamente.
        u = rand() - 1 #Se asigna una condición inicial u0 aleatoriamente.
        ax = axes()
        vec1 = Runge_Kutta_orden_4_vec(f7,lista,[x,u])   
        listx3 = map(x->x[1],vec1)
        listx4 = map(x->x[2],vec1)
    
        xlabel("x1")
        ylabel("x2"),
        plot(listx3,listx4,label="x1(0)=$x,x2(0)=$u");
        legend(bbox_to_anchor = [1.05,1],loc = 2,borderaxespad = 0)
        ax[:set_position]([0.06,0.06,0.8,0.8])
    end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64d10bced0>)

# %%
lista = 0:0.01:10 #Se define una lista de t.
    for i in 1:20 #Se realiza un for donde se grafica x para 20 condiciones iniciales aleatorias.
        x = rand() - 1 #Se asigna una condición inicial x0 aleatoriamente.
        u = rand() - 1 #Se asigna una condición inicial u0 aleatoriamente.
        ax = axes()
        vec1 = Runge_Kutta_orden_4_vec(f8,lista,[x,u])   
        listx3 = map(x->x[1],vec1)
        listx4 = map(x->x[2],vec1)
    
        xlabel("x1")
        ylabel("x2"),
        plot(listx3,listx4,label="x1(0)=$x,x2(0)=$u");
        legend(bbox_to_anchor = [1.05,1],loc = 2,borderaxespad = 0)
        ax[:set_position]([0.06,0.06,0.8,0.8])
    end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64cf844350>)

# %%
lista = 0:0.01:10 #Se define una lista de t.
    for i in 1:20 #Se realiza un for donde se grafica x para 20 condiciones iniciales aleatorias.
        x = rand() - 1 #Se asigna una condición inicial x0 aleatoriamente.
        u = rand() - 1 #Se asigna una condición inicial u0 aleatoriamente.
        ax = axes()
        vec1 = Runge_Kutta_orden_4_vec(f9,lista,[x,u])   
        listx3 = map(x->x[1],vec1)
        listx4 = map(x->x[2],vec1)
    
        xlabel("x1")
        ylabel("x2"),
        plot(listx3,listx4,label="x1(0)=$x,x2(0)=$u");
        legend(bbox_to_anchor = [1.05,1],loc = 2,borderaxespad = 0)
        ax[:set_position]([0.06,0.06,0.8,0.8])
    end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64d0c27f10>)

# %%
lista = 0:0.01:10 #Se define una lista de t.
    for i in 1:20 #Se realiza un for donde se grafica x para 20 condiciones iniciales aleatorias.
        x = rand() - 1 #Se asigna una condición inicial x0 aleatoriamente.
        u = rand() - 1 #Se asigna una condición inicial u0 aleatoriamente.
        ax = axes()
        vec1 = Runge_Kutta_orden_4_vec(f10,lista,[x,u])   
        listx3 = map(x->x[1],vec1)
        listx4 = map(x->x[2],vec1)
    
        xlabel("x1")
        ylabel("x2"),
        plot(listx3,listx4,label="x1(0)=$x,x2(0)=$u");
        legend(bbox_to_anchor = [1.05,1],loc = 2,borderaxespad = 0)
        ax[:set_position]([0.06,0.06,0.8,0.8])
    end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f64cf982c10>)
